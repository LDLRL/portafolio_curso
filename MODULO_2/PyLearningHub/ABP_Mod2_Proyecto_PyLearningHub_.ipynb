# %% [markdown]
# #PyLearningHub

# %%
class CursoPython:
    def __init__(self):
        """
        Inicializa una nueva instancia del curso.
        Crea el diccionario de progreso y almacena el nombre del alumno.
        """
        self.progreso = {}
        self.nombre_alumno = ""

    def iniciar(self):
        """
        - Inicia la experiencia del curso:
        - Solicita el nombre del alumno.
        - Muestra un mensaje de bienvenida.
        - Inicializa el progreso del alumno.
        """
        print("""
========================================
Bienvenido a PyLearningHub !!
========================================
Este curso te llevará de principiante a avanzado en Python.
Ejecuta cada celda paso a paso y sigue las explicaciones.
""")

        while True:
            nombre = input("¿Cómo te llamas? ").strip()
            if not nombre or nombre.isnumeric():
                print("Por favor, ingresa un nombre válido (no vacío ni numérico).")
            else:
                break

        self.nombre_alumno = nombre.capitalize()
        print(f"\n¡Bienvenido/a, {self.nombre_alumno}! Prepárate para aprender Python de forma práctica y divertida.\n")
        self.inicializar_progreso()

    def inicializar_progreso(self):
        """
        Inicializa el progreso del alumno si no está inicializado.
        """
        if self.nombre_alumno not in self.progreso:
            self.progreso[self.nombre_alumno] = {"lecciones_aprobadas": []}

    def mostrar_progreso(self):
        """
        Muestra el progreso del alumno.
        """
        print(f"\nProgreso de {self.nombre_alumno}:")
        aprobadas = self.progreso[self.nombre_alumno]["lecciones_aprobadas"]
        if aprobadas:
            for leccion in aprobadas:
                print(f"✔ {leccion}")
        else:
            print("Aún no has aprobado ninguna lección.")

    def menu_curso(self):
        """
        Muestra el menú principal del curso.
        """
        while True:
            print("\n=== MENÚ PRINCIPAL DE PYLEARNINGHUB ===")
            print("[1] Lección 1: Sentencias Básicas")
            print("[2] Lección 2: Estructuras de Datos y Sentencias Iterativas")
            print("[3] Lección 3: Funciones y Módulos")
            print("[4] Lección 4: Manejo de Excepciones")
            print("[5] Lección 5: POO")
            print("[6] Lección 6: Uso Avanzado del Lenguaje")
            print("[7] Proyecto Final (desbloqueado al aprobar todas las lecciones)")
            print("[8] Ver progreso")
            print("[9] Ver resumen final")
            print("[0] Salir del curso")
            opcion = input("Selecciona una opción: ").strip()

            if opcion == "1":
                self.leccion_1()
            elif opcion == "2":
                self.leccion_2()
            elif opcion == "3":
                self.leccion_3()
            elif opcion == "4":
                self.leccion_4()
            elif opcion == "5":
                self.leccion_5()
            elif opcion == "6":
                self.leccion_6()
            elif opcion == "7":
                self.proyecto_final()
            elif opcion == "8":
                self.mostrar_progreso()
            elif opcion == "9":
                self.mostrar_resumen_final()
            elif opcion == "0":
                print(f"\nGracias por usar PyLearningHub, {self.nombre_alumno}. ¡Hasta pronto!")
                break
            else:
                print("Opción inválida. Por favor, elige un número del 0 al 9.")

#---------------------------------
        #Lección 1: Sentencias Básicas del Lenguaje
#---------------------------------

    def leccion_1(self):
        """
        Ejecuta la lección 1: Sentencias Básicas del Lenguaje.
        """
        print("=" * 60)
        print(f"Lección 1: Sentencias Básicas del Lenguaje Python")
        print("=" * 60)
        print(f"Bienvenido/a {self.nombre_alumno} a la primera lección.")
        print("""
Esta lección cubre los temas fundamentales que necesitas para empezar a programar:

1. Variables y Operadores
2. Condicionales (`if`, `else`)
3. Bucles (`for` y `while`)

Recurso recomendado para repasar: https://www.w3schools.com/python/python_syntax.asp
""")

        while True:
            print("\n¿Qué tema deseas explorar?")
            print("[1] Variables y Operadores")
            print("[2] Condicionales")
            print("[3] Bucles (for y while)")
            print("[4] Evaluación")
            print("[5] Salir de la Lección 1")
            opcion = input("Elige una opción (1-5): ").strip()

            if opcion == "1":
                print("\n--- Variables y Operadores ---")
                print("""
Las variables almacenan datos. En Python, no necesitas declarar el tipo.
Por ejemplo: `x = 5`

Los operadores permiten realizar operaciones:
- Aritméticos: +, -, *, /, %
- Comparación: >, <, ==, !=, >=, <=
- Lógicos: and, or, not

Ejemplo: `x > y` devuelve True si x es mayor que y.
""")
                try:
                    x = int(input("Ingresa un número (x): "))
                    y = int(input("Ingresa otro número (y): "))
                    print(f"Suma: {x} + {y} = {x + y}")
                    print(f"Comparación: ¿x > y? → {'Sí' if x > y else 'No'}")
                    print(f"¿x es igual a y? → {x == y}")
                except Exception as e:
                    print("Error:", e)

            elif opcion == "2":
                print("\n--- Condicionales ---")
                print("""

Los condicionales permiten tomar decisiones en el código.

Ejemplo:
if x > y:
print("x es mayor")
else:
print("y es mayor o igual")
""")
                try:
                    x = int(input("Ingresa el valor de x: "))
                    y = int(input("Ingresa el valor de y: "))
                    if x > y:
                        print("Resultado: x es mayor que y.")
                    elif x == y:
                        print("Resultado: x es igual a y.")
                    else:
                        print("Resultado: x es menor que y.")
                except Exception as e:
                    print("Error:", e)

            elif opcion == "3":
                print("\n--- Bucles: for y while ---")
                print("""
Los bucles permiten repetir instrucciones de forma automática.

🔹 El bucle `for` se usa cuando sabes cuántas veces quieres repetir algo.
🔹 El bucle `while` se usa cuando quieres repetir mientras se cumpla una condición.

Vamos a ver ambos ejemplos con explicaciones paso a paso.
""")
                try:
                    print("\n--- Ejemplo con bucle for ---")
                    print("Vamos a contar del 1 al 3 usando `for`.")
                    print("Esto significa que el código se repetirá 3 veces automáticamente.")
                    for i in range(1, 4):
                        print(f"➡ Iteración número {i}: el valor de 'i' es {i}")
                    print("Fin del bucle for. Hemos contado del 1 al 3.")

                    print("\n--- Ejemplo con bucle while ---")
                    print("Ahora vamos a usar `while` para contar desde 0 hasta 2.")
                    print("El bucle continuará mientras la condición `contador < 3` sea verdadera.")
                    contador = 0
                    while contador < 3:
                        print(f"➡ El valor de 'contador' es {contador}")
                        contador += 1
                    print("Fin del bucle while. El contador ya no cumple la condición.")
                except Exception as e:
                    print("❌ Error durante la ejecución del bloque de bucles:", e)

            elif opcion == "4":
                print("\n=== Evaluación de la Lección 1 ===")
                print("Pregunta: ¿Cuál es el símbolo de comparación para 'mayor que' en Python?")
                respuesta = input("Tu respuesta: ").strip()
                if respuesta == ">":
                    print("✅ ¡Correcto! Has comprendido los operadores de comparación.")
                    if "Sentencias Básicas" not in self.progreso[self.nombre_alumno]["lecciones_aprobadas"]:
                        self.progreso[self.nombre_alumno]["lecciones_aprobadas"].append("Sentencias Básicas")
                else:
                    print("❌ Respuesta incorrecta. Revisa la sección de operadores.")
                    print("Más info: https://www.w3schools.com/python/python_conditions.asp")

            elif opcion == "5":
                print("Saliendo de la lección 1...")
                break
            else:
                print("Opción inválida. Elige del 1 al 5.")

        self.mostrar_progreso()
#---------------------------------
        #Lección 2: Estructuras de Datos y Sentencias Iterativas
#---------------------------------
    def leccion_2(self):
        """
        Ejecuta la lección 2: Estructuras de Datos y Sentencias Iterativas.
        """
        nombre_alumno = self.nombre_alumno
        print("=" * 60)
        print("Lección 2: Estructuras de Datos y Sentencias Iterativas")
        print("=" * 60)
        print(f"Hola {nombre_alumno}, bienvenido/a a la segunda lección.")
        print("""
Esta lección cubre estructuras de datos clave y cómo usarlas junto con bucles para controlar el flujo de un programa:

1. Listas - colecciones ordenadas y modificables.
2. Diccionarios - pares clave-valor para acceso rápido.
3. Conjuntos - colecciones de elementos únicos.
4. Comprensión de listas - crear listas con sintaxis compacta.
5. Evaluación final.

Recurso recomendado: https://www.w3schools.com/python/python_data_structures.asp
""")

        while True:
            print("\n¿Qué tema quieres explorar?")
            print("[1] Listas")
            print("[2] Diccionarios")
            print("[3] Conjuntos")
            print("[4] Comprensión de listas")
            print("[5] Evaluación")
            print("[6] Salir de la Lección 2")
            opcion = input("Elige una opción (1-6): ").strip()

            if opcion == "1":
                print("\n--- Listas ---")
                print("""
Las listas en Python son colecciones ordenadas y modificables. Puedes agregar, eliminar y modificar elementos.

Ejemplo:
""")
                try:
                    lista = ["manzanas", "leche", "pan"]
                    print("Lista inicial:", lista)
                    lista.append("huevos")
                    print("Después de agregar 'huevos':", lista)
                except Exception as e:
                    print("Error al trabajar con listas:", e)

            elif opcion == "2":
                print("\n--- Diccionarios ---")
                print("""
Los diccionarios almacenan pares clave-valor, lo que permite acceder a los datos de forma rápida mediante la clave.

Ejemplo:
""")
                try:
                    notas = {"Juan": 85, "Ana": 92, "Luis": 78}
                    print("Nota de Ana:", notas["Ana"])
                    notas["Luis"] = 80  # Actualizar valor
                    print("Notas actualizadas:", notas)
                except Exception as e:
                    print("Error al trabajar con diccionarios:", e)

            elif opcion == "3":
                print("\n--- Conjuntos ---")
                print("""
Los conjuntos almacenan solo elementos únicos, sin orden garantizado.

Ejemplo:
""")
                try:
                    palabras = ["hola", "hola", "python", "curso"]
                    unicas = set(palabras)
                    print("Palabras originales:", palabras)
                    print("Palabras únicas (conjunto):", unicas)
                except Exception as e:
                    print("Error al trabajar con conjuntos:", e)

            elif opcion == "4":
                print("\n--- Comprensión de listas ---")
                print("""
La comprensión de listas permite crear listas de forma compacta y eficiente.

Ejemplo:
""")
                try:
                    numeros = [x for x in range(1, 6)]
                    cuadrados = [x**2 for x in numeros]
                    print("Números:", numeros)
                    print("Cuadrados:", cuadrados)
                except Exception as e:
                    print("Error en comprensión de listas:", e)

            elif opcion == "5":
                print("\n=== Evaluación Lección 2 ===")
                pregunta = "¿Qué estructura permite almacenar pares clave-valor en Python? "
                respuesta = input(pregunta).strip().lower()
                if respuesta in ["diccionario", "dictionary", "diccionarios", "dictionaries"]:
                    print("✔ ¡Muy bien! Puedes pasar a la siguiente lección.")
                    if "Estructuras de Datos y Sentencias Iterativas" not in self.progreso[nombre_alumno]["lecciones_aprobadas"]:
                        self.progreso[nombre_alumno]["lecciones_aprobadas"].append("Estructuras de Datos y Sentencias Iterativas")
                else:
                    print("❌ Respuesta incorrecta. Consulta: https://www.w3schools.com/python/python_dictionaries.asp")

            elif opcion == "6":
                print("Saliendo de la Lección 2...")
                break

            else:
                print("Opción inválida. Por favor elige un número entre 1 y 6.")

        self.mostrar_progreso()
#---------------------------------
        #Lección 3: Funciones y Módulos
#---------------------------------
    def leccion_3(self):
        """
        Ejecuta la lección 3: Funciones y Módulos.
        """
        nombre_alumno = self.nombre_alumno
        print("=" * 60)
        print("Lección 3: Funciones y Módulos")
        print("=" * 60)
        print(f"Hola {nombre_alumno}, bienvenido/a a la tercera lección.")
        print("""
Esta lección cubre cómo organizar tu código usando funciones y módulos:

1. Funciones - creación y llamada.
2. Módulos - importar y reutilizar código.
3. Docstrings y ayuda integrada.
4. Funciones con múltiples retornos.
5. *args y **kwargs - argumentos flexibles.
6. Evaluación final.

Recurso recomendado: https://www.w3schools.com/python/python_functions.asp
""")

        while True:
            print("\n¿Qué tema quieres explorar?")
            print("[1] Funciones: definición y uso")
            print("[2] Módulos en Python")
            print("[3] Documentación con docstrings y help()")
            print("[4] Funciones que retornan múltiples valores")
            print("[5] Argumentos variables: *args y **kwargs")
            print("[6] Evaluación")
            print("[7] Salir de la Lección 3")
            opcion = input("Elige una opción (1-7): ").strip()

            if opcion == "1":
                print("\n--- Funciones: definición y uso ---")
                print("""
Las funciones son bloques de código reutilizables. Se definen con `def` y pueden tener parámetros y retornar valores.

Ejemplo:
""")
                try:
                    def saludar(nombre):
                        return f"Hola, {nombre}. ¡Bienvenido a Python!"

                    def cuadrado(n):
                        return n * n

                    print("Resultado de saludar(nombre_alumno):", saludar(nombre_alumno))
                    numero = int(input("Ingresa un número para calcular su cuadrado: "))
                    print("El cuadrado es:", cuadrado(numero))
                except Exception as e:
                    print("Error:", e)

            elif opcion == "2":
                print("\n--- Módulos en Python ---")
                print("""
Un módulo es un archivo `.py` que contiene funciones, variables o clases. Puedes importar módulos para reutilizar código.

Ejemplo de módulo incorporado:
""")
                try:
                    import math
                    num = float(input("Ingresa un número para calcular su raíz cuadrada: "))
                    print("Raíz cuadrada:", round(math.sqrt(num), 2))
                except Exception as e:
                    print("Error con módulo math:", e)

            elif opcion == "3":
                print("\n--- Documentación con docstrings y help() ---")
                print("""
Puedes documentar una función con una cadena triple (docstring).
`help()` muestra esa información al usuario.

Ejemplo:
""")
                def multiplicar(a, b):
                    """Multiplica dos números y devuelve el resultado."""
                    return a * b

                print("Ejecutando help(multiplicar)...\n")
                help(multiplicar)

            elif opcion == "4":
                print("\n--- Funciones que retornan múltiples valores ---")
                print("""
Una función puede retornar varios valores en forma de tupla.

Ejemplo:
""")
                def operaciones(a, b):
                    """Retorna suma, resta, multiplicación y división."""
                    return a + b, a - b, a * b, a / b

                try:
                    x = int(input("Ingresa primer número: "))
                    y = int(input("Ingresa segundo número: "))
                    suma, resta, mult, div = operaciones(x, y)
                    print(f"Suma: {suma}, Resta: {resta}, Multiplicación: {mult}, División: {div:.2f}")
                except Exception as e:
                    print("Error en operaciones:", e)

            elif opcion == "5":
                print("\n--- Argumentos variables: *args y **kwargs ---")
                print("""
*args permite enviar muchos argumentos (sin nombre) como una tupla.
**kwargs permite enviar argumentos nombrados como un diccionario.

Ejemplo:
""")
                def suma_total(*args):
                    """Suma todos los argumentos recibidos."""
                    return sum(args)

                def mostrar_info(**kwargs):
                    """Muestra información en forma de diccionario."""
                    print("Información:")
                    for clave, valor in kwargs.items():
                        print(f"{clave}: {valor}")

                print("Ejemplo de *args: suma_total(1, 2, 3) =", suma_total(1, 2, 3))
                print("Ejemplo de **kwargs:")
                mostrar_info(nombre="Ana", edad=25, curso="Python")

            elif opcion == "6":
                print("\n=== Evaluación Lección 3 ===")
                pregunta = "¿Qué palabra clave se usa para definir una función en Python? "
                respuesta = input(pregunta).strip().lower()
                if respuesta == "def":
                    print("✔ ¡Muy bien! Puedes pasar a la siguiente lección.")
                    if "Funciones y Módulos" not in self.progreso[nombre_alumno]["lecciones_aprobadas"]:
                        self.progreso[nombre_alumno]["lecciones_aprobadas"].append("Funciones y Módulos")
                else:
                    print("✘ Respuesta incorrecta. Consulta: https://www.w3schools.com/python/python_functions.asp")

            elif opcion == "7":
                print("Saliendo de la Lección 3...")
                break

            else:
                print("Opción inválida. Por favor elige un número entre 1 y 7.")

        self.mostrar_progreso()

#---------------------------------
        #Lección 4: Manejo de Excepciones
#---------------------------------
    def leccion_4(self):
        """
        Ejecuta la lección 4: Manejo de Excepciones.
        """
        nombre_alumno = self.nombre_alumno
        print("=" * 60)
        print("Lección 4: Manejo de Excepciones")
        print("=" * 60)
        print(f"Hola {nombre_alumno}, bienvenido/a a la cuarta lección.")
        print("""
Esta lección te enseñará a capturar y gestionar errores en Python para hacer tus programas más robustos.

Temas que cubriremos:
1. ¿Qué es una excepción?
2. try / except
3. else y finally
4. Excepciones comunes
5. Evaluación

Recurso recomendado: https://www.w3schools.com/python/python_try_except.asp
""")

        while True:
            print("\n¿Qué tema quieres explorar?")
            print("[1] ¿Qué es una excepción?")
            print("[2] Uso básico de try / except")
            print("[3] Uso de else y finally")
            print("[4] Excepciones comunes")
            print("[5] Evaluación")
            print("[6] Salir de la Lección 4")
            opcion = input("Elige una opción (1-6): ").strip()

            if opcion == "1":
                print("\n--- ¿Qué es una excepción? ---")
                print("""
Una excepción es un error que ocurre durante la ejecución del programa.
En lugar de detenerse abruptamente, podemos manejar el error y continuar ejecutando.

Ejemplos de errores comunes:
- Dividir por cero
- Acceder a una variable inexistente
- Convertir texto a número de forma incorrecta

Python nos permite capturar estos errores usando bloques especiales.
""")

            elif opcion == "2":
                print("\n--- Uso básico de try / except ---")
                print("""
Sintaxis básica para manejar excepciones:

try:
    # Código que puede lanzar un error
except TipoDeError:
    # Código que se ejecuta si ocurre ese error

Ejemplo:
""")
                try:
                    valor = int(input("Ingresa un número (prueba con letras): "))
                    print("Número ingresado:", valor)
                except ValueError:
                    print("Error: Debes ingresar un número válido.")

            elif opcion == "3":
                print("\n--- Uso de else y finally ---")
                print("""
Además del bloque try/except, puedes usar:

- else: se ejecuta si no ocurre ninguna excepción.
- finally: se ejecuta siempre, ocurra o no una excepción.

Ejemplo completo:
""")
                try:
                    numero = int(input("Ingresa un número válido: "))
                except ValueError:
                    print("❌ Ocurrió un error al convertir el dato.")
                else:
                    print("✅ Conversión exitosa.")
                finally:
                    print("✔ Bloque finally ejecutado.")

            elif opcion == "4":
                print("\n--- Excepciones comunes ---")
                print("""
Las más frecuentes en Python:

- ValueError: tipo de dato incorrecto (por ejemplo, texto en lugar de número)
- ZeroDivisionError: división entre cero
- TypeError: operación entre tipos incompatibles
- IndexError: acceso a posición inexistente en una lista

Ejemplo interactivo:
""")
                try:
                    a = int(input("Ingresa el numerador: "))
                    b = int(input("Ingresa el denominador: "))
                    resultado = a / b
                except ZeroDivisionError:
                    print("❌ No se puede dividir por cero.")
                except ValueError:
                    print("❌ Debes ingresar números enteros.")
                else:
                    print(f"✅ Resultado: {resultado}")
                finally:
                    print("✔ Fin del intento de división segura.")

            elif opcion == "5":
                print("\n=== Evaluación Lección 4 ===")
                pregunta = "¿Cuál es el nombre del bloque que se usa para capturar errores en Python? "
                respuesta = input(pregunta).strip().lower()
                if respuesta == "except":
                    print("✔ ¡Correcto! Puedes continuar con la siguiente lección.")
                    if "Manejo de Excepciones" not in self.progreso[nombre_alumno]["lecciones_aprobadas"]:
                        self.progreso[nombre_alumno]["lecciones_aprobadas"].append("Manejo de Excepciones")
                else:
                    print("✘ Respuesta incorrecta. Consulta: https://www.w3schools.com/python/python_try_except.asp")

            elif opcion == "6":
                print("Saliendo de la Lección 4...")
                break

            else:
                print("Opción inválida. Por favor elige un número entre 1 y 6.")

        self.mostrar_progreso()

#---------------------------------
        #Lección 5: Programación Orientada a Objetos (POO)
#---------------------------------
    def leccion_5(self):
        """
        Ejecuta la lección 5: Programación Orientada a Objetos (POO).
        """
        nombre_alumno = self.nombre_alumno
        print("=" * 60)
        print("Lección 5: Programación Orientada a Objetos (POO)")
        print("=" * 60)
        print(f"Hola {nombre_alumno}, bienvenido/a a la quinta lección.")
        print("""
Esta lección te introduce a uno de los conceptos más importantes en la programación moderna: la Programación Orientada a Objetos (POO).

Temas que cubriremos:
1. ¿Qué es la POO?
2. Clases y Objetos
3. Atributos y Métodos
4. Herencia
5. Evaluación

Recurso recomendado: https://www.w3schools.com/python/python_classes.asp
""")

        while True:
            print("\n¿Qué tema quieres explorar?")
            print("[1] ¿Qué es la POO?")
            print("[2] Clases y Objetos")
            print("[3] Atributos y Métodos")
            print("[4] Herencia")
            print("[5] Evaluación")
            print("[6] Salir de la Lección 5")
            opcion = input("Elige una opción (1-6): ").strip()

            if opcion == "1":
                print("\n--- ¿Qué es la POO? ---")
                print("""
La Programación Orientada a Objetos es un paradigma que organiza el código en torno a objetos.
Cada objeto es una combinación de datos (atributos) y comportamientos (métodos).

Beneficios:
- Reutilización de código mediante clases.
- Organización y mantenimiento más sencillo.
- Modela el mundo real más naturalmente.
""")

            elif opcion == "2":
                print("\n--- Clases y Objetos ---")
                print("""
Una clase es un plano para crear objetos. Un objeto es una instancia concreta de una clase.

Sintaxis básica:

class Persona:
    def __init__(self, nombre):
        self.nombre = nombre

    def saludar(self):
        print(f"Hola, soy {self.nombre}")

Ejemplo:
""")
                class Persona:
                    def __init__(self, nombre):
                        self.nombre = nombre

                    def saludar(self):
                        print(f"Hola, soy {self.nombre}")

                nombre_obj = input("Ingresa un nombre para crear un objeto Persona: ")
                persona1 = Persona(nombre_obj)
                print("\nLlamando al método saludar:")
                persona1.saludar()

            elif opcion == "3":
                print("\n--- Atributos y Métodos ---")
                print("""
Atributos: características que describen al objeto.
Métodos: acciones que el objeto puede realizar.

En el ejemplo anterior:
- 'nombre' es un atributo.
- 'saludar()' es un método.

Puedes acceder a los atributos así:
print(persona1.nombre)

Puedes llamar a métodos así:
persona1.saludar()
""")

            elif opcion == "4":
                print("\n--- Herencia ---")
                print("""
La herencia permite que una clase (hija) herede atributos y métodos de otra clase (padre).

Ejemplo:

class Estudiante(Persona):
    def __init__(self, nombre, curso):
        super().__init__(nombre)
        self.curso = curso

    def mostrar_info(self):
        print(f"Soy {self.nombre} y estoy en el curso de {self.curso}")

Demostración:
""")
                class Persona:
                    def __init__(self, nombre):
                        """Constructor de la clase Persona."""
                        self.nombre = nombre

                    def saludar(self):
                        """Método para saludar."""
                        print(f"Hola, soy {self.nombre}")

                class Estudiante(Persona):
                    def __init__(self, nombre, curso):
                        """Constructor de la clase Estudiante."""
                        super().__init__(nombre)
                        self.curso = curso

                    def mostrar_info(self):
                        """Método para mostrar información del estudiante."""
                        print(f"Soy {self.nombre} y estoy en el curso de {self.curso}")

                nombre_est = input("Nombre del estudiante: ")
                curso_est = input("Curso del estudiante: ")
                estudiante = Estudiante(nombre_est, curso_est)
                print("\nLlamando a métodos:")
                estudiante.saludar()
                estudiante.mostrar_info()

            elif opcion == "5":
                print("\n=== Evaluación Lección 5 ===")
                pregunta = "¿Cuál es la palabra clave que se usa para definir una clase en Python? "
                respuesta = input(pregunta).strip().lower()
                if respuesta == "class":
                    print("✔ ¡Correcto! Has comprendido cómo se definen las clases.")
                    if "POO" not in self.progreso[nombre_alumno]["lecciones_aprobadas"]:
                        self.progreso[nombre_alumno]["lecciones_aprobadas"].append("POO")
                else:
                    print("✘ Respuesta incorrecta. Revisa la sintaxis de clases en Python.")

            elif opcion == "6":
                print("Saliendo de la Lección 5...")
                break

            else:
                print("Opción inválida. Por favor elige un número entre 1 y 6.")

        self.mostrar_progreso()

#---------------------------------
        #Lección 6: Uso Avanzado del Lenguaje
#---------------------------------
    def leccion_6(self):
        """
        Ejecuta la lección 6: Uso Avanzado del Lenguaje.
        """
        nombre_alumno = self.nombre_alumno
        print("=" * 60)
        print("Lección 6: Uso Avanzado del Lenguaje")
        print("=" * 60)
        print(f"Hola {nombre_alumno}, bienvenido/a a la sexta lección de Python.")
        print("""
En esta lección exploraremos herramientas más potentes y flexibles de Python,
que te permitirán escribir código más conciso, reutilizable y profesional.

Recurso recomendado: https://www.w3schools.com/python/python_lambda.asp
""")

        while True:
            print("\n¿Qué tema quieres explorar?")
            print("[1] Funciones como objetos de primera clase")
            print("[2] Funciones lambda")
            print("[3] Tipado dinámico y fuerte")
            print("[4] Argumentos arbitrarios y desempaquetado")
            print("[5] Comprensión de listas avanzada")
            print("[6] Evaluación")
            print("[7] Salir de la Lección 6")
            opcion = input("Elige una opción (1-7): ").strip()

            if opcion == "1":
                print("\n--- Funciones como objetos de primera clase ---")
                print("""
En Python, las funciones son objetos de primera clase:
- Pueden asignarse a variables.
- Pueden pasarse como argumentos a otras funciones.
- Pueden retornarse desde otras funciones.

Ejemplo práctico:
""")
                def saludar():
                    """Función para saludar."""
                    print("Hola desde la función saludar")

                def ejecutar_funcion(func):
                    """Ejecuta una función pasada como argumento."""
                    print("Voy a ejecutar una función:")
                    func()

                ejecutar_funcion(saludar)

            elif opcion == "2":
                print("\n--- Funciones lambda ---")
                print("""
Las funciones lambda son funciones anónimas definidas en una sola línea.
Se usan para funciones pequeñas y rápidas, especialmente como argumentos.

Ejemplo:
""")
                doble = lambda x: x * 2
                print("Función lambda que dobla un número.")
                print("El doble de 5 es:", doble(5))

            elif opcion == "3":
                print("\n--- Tipado dinámico y fuerte ---")
                print("""
Python asigna el tipo de variable dinámicamente, sin que tengas que declararlo.
Pero es un lenguaje de tipado fuerte: no mezcla tipos incompatibles sin conversión explícita.

Ejemplo:
""")
                x = "5"
                try:
                    resultado = x + 3
                except Exception as e:
                    print("Error:", e)

                print("Solución: convierte x a entero con int(x):", int(x) + 3)

            elif opcion == "4":
                print("\n--- Argumentos arbitrarios y desempaquetado ---")
                print("""
*args permite recibir un número variable de argumentos posicionales.
**kwargs permite recibir un número variable de argumentos nombrados.

Ejemplo:
""")
                def suma(*numeros):
                    return sum(numeros)

                print("Suma de varios números (1, 2, 3, 4):", suma(1, 2, 3, 4))

                def mostrar_info(**kwargs):
                    for clave, valor in kwargs.items():
                        print(f"{clave}: {valor}")

                print("Información personal:")
                mostrar_info(nombre="Ana", edad=30, ciudad="Madrid")

            elif opcion == "5":
                print("\n--- Comprensión de listas avanzada ---")
                print("""
Las listas por comprensión permiten crear listas de forma concisa,
incluyendo condiciones y transformaciones.

Ejemplo:
""")
                pares = [x for x in range(10) if x % 2 == 0]
                print("Números pares del 0 al 9:", pares)

            elif opcion == "6":
                print("\n=== Evaluación Lección 6 ===")
                pregunta = "¿Qué palabra se utiliza en Python para definir una función anónima en una sola línea? "
                respuesta = input(pregunta).strip().lower()
                if respuesta == "lambda":
                    print("✔ Correcto. Has comprendido el uso de funciones lambda.")
                    if "Uso Avanzado del Lenguaje" not in self.progreso[nombre_alumno]["lecciones_aprobadas"]:
                        self.progreso[nombre_alumno]["lecciones_aprobadas"].append("Uso Avanzado del Lenguaje")
                else:
                    print("❌ Revisa el ejemplo donde usamos funciones lambda.")

            elif opcion == "7":
                print("Saliendo de la Lección 6...")
                break

            else:
                print("Opción inválida. Por favor elige un número entre 1 y 7.")

        self.mostrar_progreso()

#---------------------------------
        #Proyecto final
#---------------------------------
    def proyecto_final(self):
        """
        Muestra el proyecto final solo si se han aprobado todas las lecciones.
        """
        nombre_alumno = self.nombre_alumno
        lecciones_totales = [
            "Sentencias Básicas",
            "Estructuras de Datos y Sentencias Iterativas",
            "Funciones y Módulos",
            "Manejo de Excepciones",
            "POO",
            "Uso Avanzado del Lenguaje"
        ]
        aprobadas = self.progreso.get(nombre_alumno, {}).get("lecciones_aprobadas", [])

        if all(leccion in aprobadas for leccion in lecciones_totales):
            print(f"""
Hola {nombre_alumno}, llegaste a la etapa final del curso PyLearningHub.

Proyecto Final:
Debes crear un programa que simule un sistema simple que incluya:

- Una clase que defina un objeto con al menos 2 atributos y 2 métodos.
- Uso de al menos una función externa a la clase.
- Manejo de errores básicos con try-except.
- Uso de listas o diccionarios para almacenar datos.
- Interacción con el usuario mediante input().

Ejemplo: un sistema de gestión de libros, productos, estudiantes, etc.

¡Manos a la obra! Escribe tu código y compártelo.
""")
        else:
            print(f"\n{nombre_alumno}, aún no has completado todas las lecciones necesarias para acceder al proyecto final.")


#---------------------------------
        #Resumen y despedida del curso
#---------------------------------
    def mostrar_resumen_final(self):
        """
        Muestra el resumen y despedida del curso si se han completado todas las lecciones.
        """
        nombre_alumno = self.nombre_alumno
        lecciones_totales = [
            "Sentencias Básicas",
            "Estructuras de Datos y Sentencias Iterativas",
            "Funciones y Módulos",
            "Manejo de Excepciones",
            "POO",
            "Uso Avanzado del Lenguaje"
        ]

        print("\n" + "=" * 50)
        print(f"Resumen de tu avance, {nombre_alumno}")
        print("=" * 50)

        aprobadas = self.progreso[nombre_alumno].get("lecciones_aprobadas", [])
        print(f"Lecciones completadas: {len(aprobadas)} de {len(lecciones_totales)}\n")

        for lec in lecciones_totales:
            estado = "✅ Aprobada" if lec in aprobadas else "❌ Pendiente"
            print(f"- {lec}: {estado}")

        if len(aprobadas) == len(lecciones_totales):
            print(f"""
¡Felicidades, {nombre_alumno}!

Has completado todas las lecciones del curso PyLearningHub.

Esperamos que esta experiencia te haya ayudado a fortalecer tus conocimientos en Python.

¡Mucho éxito en tus futuros proyectos!
""")
        else:
            print(f"""
¡Buen trabajo, {nombre_alumno}!

Has avanzado muy bien, pero aún te faltan algunas lecciones para completar el curso.

¡Sigue practicando y vuelve cuando estés listo/a para continuar!
""")

# %%
# Crear una instancia del curso
curso = CursoPython()

#Aquí estamos creando una instancia de la clase CursoPython.
#Esto significa que curso es un objeto que contiene toda la lógica y datos del curso,
#incluyendo el progreso, nombre del alumno y métodos para manejar las lecciones.

#--------------------------------
# Iniciar el curso: solicita nombre, muestra bienvenida y prepara el progreso
curso.iniciar()

#Este método inicia la experiencia del curso.
#Generalmente, solicita el nombre del alumno, valida que sea correcto y prepara la estructura de datos para registrar su progreso.
#También puede mostrar un mensaje de bienvenida y cualquier otra configuración inicial necesaria.

#------------------------------------------
# Mostrar el menú principal del curso para que el alumno elija lecciones o acciones
curso.menu_curso()

#Aquí se llama al método que muestra un menú principal o central
#para que el alumno pueda elegir qué lección quiere tomar o qué acción realizar (por ejemplo, revisar progreso, salir, etc).
#Este menú mantiene el flujo de interacción dentro del curso, permitiendo avanzar, regresar o salir.
# Out:
# ...
# Bienvenido a PyLearningHub !!
# ...
# Este curso te llevará de principiante a avanzado en Python.
# Ejecuta cada celda paso a paso y sigue las explicaciones.
#
# ¿Cómo te llamas? lore
#
# ¡Bienvenido/a, Lore! Prepárate para aprender Python de forma práctica y divertida.
#
#
# === MENÚ PRINCIPAL DE PYLEARNINGHUB ===
# [1] Lección 1: Sentencias Básicas
# [2] Lección 2: Estructuras de Datos y Sentencias Iterativas
# [3] Lección 3: Funciones y Módulos
# [4] Lección 4: Manejo de Excepciones
# [5] Lección 5: POO
# [6] Lección 6: Uso Avanzado del Lenguaje
# [7] Proyecto Final (desbloqueado al aprobar todas las lecciones)
# [8] Ver progreso
# [9] Ver resumen final
# [0] Salir del curso
# Selecciona una opción: 6
# ...
# Lección 6: Uso Avanzado del Lenguaje
# ...
# Hola Lore, bienvenido/a a la sexta lección de Python.
#
# En esta lección exploraremos herramientas más potentes y flexibles de Python,
# que te permitirán escribir código más conciso, reutilizable y profesional.
#
# ...
